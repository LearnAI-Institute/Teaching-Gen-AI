# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")
# Out:
# c:\Users\user\Documents\Teaching-Gen-AI\venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
prompts = [
    {"role":"user", "content":"Hello, My name is Muhammad Noman."},
    {"role":"ai", "content":'Hello, Muhammad Noman! How can I assist you today?'},
    {"role":"user", "content":"What is My name ?"}
]

res = llm.invoke(prompts)

# %%
res.content
# Out:
# 'Your name is Muhammad Noman. How can I assist you further?'

# %% [markdown]
# ### Manage History

# %%
history = [] ## [{"role":"user", "content":"Who is pm of india ?"}]
while True:
    query = input("User: ")
    if query.lower() in ["exit", "quit", "bye"]:
        print("Good Bye 👋")
        break

    history.append({"role":"user", "content":query})
    print("User: ", query)


    res = llm.invoke(history)
    history.append({"role":"ai", "content":res.content})
    print("AI: ", res.content, "\n")
# Out:
# User:
# AI:  Hello! How can I assist you today?
#
# User:  HEY
# AI:  Hey! How can I help you today?
#
# User:  mY NAME IS mUHAMMAD nOMAN
# AI:  Nice to meet you, Muhammad Noman! How can I assist you today?
#
# User:  its Muhammad Noman
# AI:  Apologies for the mistake! Nice to meet you, Muhammad Noman. How can I assist you today?
#
# User:  .
# AI:  If there's anything specific you'd like to know or discuss, feel free to let me know. I'm here to help!
#
# User:
# AI:  If you have any questions or need assistance, don't hesitate to ask. I'm here to help!
#
# Good Bye 👋
