# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-4o")

# %%
prompts = [
    {"role":"system", "content":"You are a JavaScript Developer ?"},
    {"role":"user", "content":"Difference b/w map and filter ?"},
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# In JavaScript, both `map` and `filter` are array methods that are used to manipulate arrays, but they serve different purposes and have different effects on the array.
#
# ### `map` Method
#
# - **Purpose**: The `map` method is used to transform elements in an array. It creates a new array by applying a function to each element of the original array, and the new array contains the results of these function applications.
# - **Return Value**: It returns a new array of the same length as the original array, but with each element transformed by the specified function.
# - **Function**: It takes a callback function as an argument. This function is called with three arguments: the current element, the index of the current element, and the array being traversed.
#
# **Example**:
# ```javascript
# const numbers = [1, 2, 3, 4];
# const squaredNumbers = numbers.map(num => num * num);
# console.log(squaredNumbers); // Output: [1, 4, 9, 16]
# ```
#
# ### `filter` Method
#
# - **Purpose**: The `filter` method is used to select elements from an array based on a condition. It creates a new array with all elements that pass the test implemented by the provided function.
# - **Return Value**: It returns a new array containing all elements of the original array that satisfy the provided condition. The length of the new array may be less than or equal to the original array.
# - **Function**: It takes a callback function as an argument. This function is called with three arguments: the current element, the index of the current element, and the array being traversed. The function should return a boolean value, where `true` includes the element in the new array, and `false` excludes it.
#
# **Example**:
# ```javascript
# const numbers = [1, 2, 3, 4];
# const evenNumbers = numbers.filter(num => num % 2 === 0);
# console.log(evenNumbers); // Output: [2, 4]
# ```
#
# ### Key Differences
#
# - **Transformation vs. Selection**: `map` is used for transforming each element of an array, while `filter` is used for selecting a subset of elements that satisfy a certain condition.
# - **Output Array Length**: The output array from `map` is always of the same length as the original, whereas the output array from `filter` can be shorter.
# - **Use Case**: Use `map` when you want to operate on each element of an array. Use `filter` when you only need a certain subset of elements that meet a specific condition.

# %%
prompts = [
    {"role":"system", "content":"You are a Python Developer ?"},
    {"role":"user", "content":"Difference b/w map and filter ?"},
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# Both `map` and `filter` are built-in Python functions used for processing iterables, but they serve different purposes and operate in distinct ways:
#
# ### `map`
#
# - **Purpose**: `map` applies a given function to each item of an iterable (like a list) and returns an iterator (or a `map` object in Python 3) that yields the transformed items.
# - **Use Case**: When you need to perform a transformation or operation on each element of the iterable.
# - **Example**:
#   ```python
#   def square(x):
#       return x * x
#
#   numbers = [1, 2, 3, 4]
#   squared_numbers = map(square, numbers)  # returns a map object
#   print(list(squared_numbers))  # Output: [1, 4, 9, 16]
#   ```
#
# ### `filter`
#
# - **Purpose**: `filter` applies a given function to each item of an iterable and returns an iterator (or a `filter` object in Python 3) containing only the items for which the function returns `True`.
# - **Use Case**: When you need to select a subset of elements from an iterable based on some condition.
# - **Example**:
#   ```python
#   def is_even(x):
#       return x % 2 == 0
#
#   numbers = [1, 2, 3, 4]
#   even_numbers = filter(is_even, numbers)  # returns a filter object
#   print(list(even_numbers))  # Output: [2, 4]
#   ```
#
# ### Key Differences
#
# - **Function Behavior**: `map` transforms elements, while `filter` selects elements.
# - **Return**: Both return an iterator, but `map` returns an iterator of transformed elements, whereas `filter` returns an iterator of the elements that satisfy a condition.
# - **Function Requirement**: The function used with `map` can return any type, whereas the function used with `filter` must return a Boolean value (`True` or `False`).
#
# Both `map` and `filter` can be very handy for concise and functional-style programming in Python.

# %%
prompts = [
    {"role":"system", "content":"You are a translator and translate input in Hindi ?"},
    {"role":"user", "content":"I love to play Cricket ?"},
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# मुझे क्रिकेट खेलना बहुत पसंद है।

# %% [markdown]
# #### Prompt Templates - Dynamic Prompts

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatOpenAI(model="gpt-4o")
out = StrOutputParser()

# %%
#### My Self Chain Node

def transform_case(result:str):
    return result.upper()

# %%
prompts = ChatPromptTemplate.from_messages([
    {"role":"system", "content":"You are a translator and translate input in {language} ?"},
    {"role":"user",  "content":"{query}"},
])

# %%
# final_prompts = prompts.format_messages(language = "Hinglish ?", 
#                                         query = "I love Python, and JavaScript ?")
# res = llm.invoke(final_prompts)
# print(res.content)
# Out:
# Main Python aur JavaScript dono ko pasand karta hoon.

# %%
# final_prompts
# Out:
# [SystemMessage(content='You are a translator and translate input in Hinglish ? ?', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='I love Python, and JavaScript ?', additional_kwargs={}, response_metadata={})]

# %%
# res = llm.invoke(prompts.invoke({"language":"Hindi", "query":"I love You ?"}))
# res.content
# Out:
# 'मैं तुमसे प्यार करता हूँ / मैं तुमसे प्यार करती हूँ।'

# %%
chains = prompts | llm

# %%
res = chains.invoke({"language":"Hinglish", "query":"I love LangChain ?"})
print(res)
# Out:
# content='Main LangChain ko pasand karta hoon.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 27, 'total_tokens': 37, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_18e61aa3bc', 'id': 'chatcmpl-DCjLFW503dmxn1lTAopIdlrZn95rN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c8f0e-3acf-7e20-ac0d-cc51546aa081-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 27, 'output_tokens': 10, 'total_tokens': 37, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
